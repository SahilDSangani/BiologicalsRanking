# %%
import pandas as pd
import numpy as np
from datetime import datetime

import sys
sys.path.append(".")  # ensures notebook can see local modules
import functions as dm

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                             Company                            Website  \
# 0   Imerys Filtration Minerals Inc.            https://www.imerys.com/
# 1        FMC Professional Solutions             https://www.fmc.com/en
# 2                   BioWorks Canada           https://bioworksinc.com/
# 3                 Lucent Bioscience     https://lucentbiosciences.com/
# 4             Blacksmith BioScience         https://blacksmithbio.com/
# 5            Winfield United Canada   https://www.winfieldunited.ca/en
# 6    Target Specialty Products Inc.  https://www.target-specialty.com/
# 7                             Orbem                  https://orbem.ai/
# 8               Summit Agro USA LLC    https://www.summitagro-usa.com/
# 9              Nufarm Americas Inc.             https://nufarm.com/us/
# 10                         Huma Gro  https://humagro.com/case-studies/
#
#     Research Reports  Lab reports  Field reports  Testimonials  News articles  \
# 0                 32           11             14             6             11
# 1                 16            5             10             5             10
# 2                 19            6             11             6             13
# 3                  8            2             15             4             14
# 4                 11           10              9             5              5
# 5                 14            6             16            13             12
# 6                  8            6              7             5             14
# 7                 35           12             18            14             42
# 8                 11            4             12             6             12
# 9                 39            4             13             2             22
# 10                24           11             42            14             22
#
#     Total Reports sentiment
# 0              74   Neutral
# 1              46   Neutral
# 2              55   Neutral
# 3              43   Neutral
# 4              40   Neutral
# 5              61   Neutral
# 6              40   Neutral
# 7             121   Neutral
# 8              45   Neutral
# 9              80   Neutral
# 10            113   Neutral

# %%
df.shape
# Out:
# (229, 9)

# %%
df.describe()
# Out:
#                  company website total_citations research_reports lab_reports  \
# count                229     229             229              229         229
# unique               229       1               1                1           1
# top     A&P Inphatec LLC
# freq                   1     229             229              229         229
#
#        field_reports testimonials news_articles sentiment
# count            229          229           229       229
# unique             1            1             1         1
# top
# freq             229          229           229       229

# %%
df.isna().sum()
# Out:
# company             0
# website             0
# total_citations     0
# research_reports    0
# lab_reports         0
# field_reports       0
# testimonials        0
# news_articles       0
# sentiment           0
# dtype: int64

# %%
manual_entry = df.sample(n=10)
manual_entry
# Out:
#                              company website total_citations research_reports  \
# 96   Imerys Filtration Minerals Inc.
# 80        FMC Professional Solutions
# 48                   BioWorks Canada
# 121                Lucent Bioscience
# 50             Blacksmith BioScience
# 225           Winfield United Canada
# 196   Target Specialty Products Inc.
# 152                            Orbem
# 189              Summit Agro USA LLC
# 142             Nufarm Americas Inc.
#
#     lab_reports field_reports testimonials news_articles sentiment
# 96
# 80
# 48
# 121
# 50
# 225
# 196
# 152
# 189
# 142
